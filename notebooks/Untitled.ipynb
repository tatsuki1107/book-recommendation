# %%
import joblib
df = joblib.load('../data/explicit.pkl')

# %%
df[df["User-ID"]==2954].index.to_numpy()
# Out:
# array([    0,  4115, 28604, 28606, 28608, 28609, 28610, 28611, 28612,
#        28613, 28617, 28618])

# %%
df[df["User-ID"].isin([2954])]
# Out:
#        User-ID        ISBN  Book-Rating   Age     city   state country  \
# 0         2954  0060973129          8.0  71.0  wichita  kansas     usa
# 4115      2954  0440235502         10.0  71.0  wichita  kansas     usa
# 28604     2954  0380973499          7.0  71.0  wichita  kansas     usa
# 28606     2954  031224116X          8.0  71.0  wichita  kansas     usa
# 28608     2954  0385319622          9.0  71.0  wichita  kansas     usa
# 28609     2954  1853673110          4.0  71.0  wichita  kansas     usa
# 28610     2954  0891415947          7.0  71.0  wichita  kansas     usa
# 28611     2954  0804100039          6.0  71.0  wichita  kansas     usa
# 28612     2954  0440236304          7.0  71.0  wichita  kansas     usa
# 28613     2954  0060183527          7.0  71.0  wichita  kansas     usa
# 28617     2954  0743201981          6.0  71.0  wichita  kansas     usa
# 28618     2954  0767908244          8.0  71.0  wichita  kansas     usa
#
# ...
